# %%
import pandas as pd

# %%
data=pd.read_csv("https://olympus.mygreatlearning.com/courses/84617/files/7485628/download?verifier=ONTVlGw74o5eojhoUR0Z8WuXlqfBqDJ6ATMce8dw&wrap=1")

# %%
data
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %%
youtube_data=data.copy()

# %% [markdown]
# # #1. Import required libraries and read the provided dataset (youtube_dislike_dataset.csv) and retrieve top5 and bottom 5 records.

# %%
data.head()  #The top five rows form the youtube data
# Out:
#       video_id                                       title  \
# 0  --0bCF-iK2E        Jadon Sancho  Magical Skills & Goals
# 1  --14w5SOEUs          Migos - Avalanche (Official Video)
# 2  --40TEbZ9Is  Supporting Actress in a Comedy: 73rd Emmys
# 3  --4tfbSyYDE     JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4  --DKkzWVh-E                Why Retaining Walls Collapse
#
#                  channel_id          channel_title         published_at  \
# 0  UC6UL29enLNe4mqwTfAyeNuw             Bundesliga  2021-07-01 10:00:00
# 1  UCGIelM2Dj3zza3xyV3pL3WQ              MigosVEVO  2021-06-10 16:00:00
# 2  UClBKH8yZRcM4AsRjDVEdjMg     Television Academy  2021-09-20 01:03:32
# 3  UCsmXiDP8S40uBeJYxvyulmA                    JO1  2021-03-03 10:00:17
# 4  UCMOqf8ab-42UUQIdVoKwjlQ  Practical Engineering  2021-12-07 13:00:00
#
#    view_count   likes  dislikes  comment_count  \
# 0     1048888   19515       226           1319
# 1    15352638  359277      7479          18729
# ...

# %%
data.tail()# The bottom five rows from the youtube data
# Out:
#           video_id                                              title  \
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id      channel_title         published_at  \
# 37417  UCEB4a5o_6KfjxHwNMnmj54Q           Lil Tjay  2021-02-12 05:03:49
# 37418  UCWJ2lWNubArHWmf3FIHbfcQ                NBA  2021-01-16 05:39:05
# 37419  UCuhAUMLzJxlP1W7mEk0_6lA            MAMAMOO  2021-06-02 09:00:10
# 37420  UC8NjnNWMsRqq11NYvHAQb1g     Master Podcast  2020-10-20 20:59:30
# 37421  UCEg25rdRZXg32iwai6N6l0w  Tottenham Hotspur  2021-05-23 21:00:31
#
#        view_count    likes  dislikes  comment_count  \
# 37417   120408275  2180780     35871          81360
# ...

# %% [markdown]
# # 2. Check the info of the dataframe and write your inferences on data types and shape of the dataset.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37422 entries, 0 to 37421
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   video_id       37422 non-null  object
#  1   title          37422 non-null  object
#  2   channel_id     37422 non-null  object
#  3   channel_title  37422 non-null  object
#  4   published_at   37422 non-null  object
#  5   view_count     37422 non-null  int64
#  6   likes          37422 non-null  int64
#  7   dislikes       37422 non-null  int64
#  8   comment_count  37422 non-null  int64
#  9   tags           37422 non-null  object
#  10  description    37422 non-null  object
#  11  comments       37264 non-null  object
# dtypes: int64(4), object(8)
# memory usage: 3.4+ MB

# %%
#Inferences

# 1)From the above information there are eleven columns and 37422 rows where in the comments column there are 158 null values and 
#     remaining columens does not have any null values the shape of the data set is 37422 rows and 12 columns

# %%
data.shape
# Out:
# (37422, 12)

# %% [markdown]
# # 3. Check for the Percentage of the missing values and drop or impute them.

# %%
data.isnull().sum()
# Out:
# video_id           0
# title              0
# channel_id         0
# channel_title      0
# published_at       0
# view_count         0
# likes              0
# dislikes           0
# comment_count      0
# tags               0
# description        0
# comments         158
# dtype: int64

# %%
158/37422
# Out:
# 0.004222115333226444

# %%
missing_values=data["comments"].isnull().sum()

# %%
missing_percentage=(missing_values/len(data.index))*100

# %%
missing_percentage  
#There are missing values in the comments column and the percentage of the of the missing values are 0.42 percentage
# Out:
# 0.4222115333226444

# %%
data.fillna(value="",inplace=True) # filling the null values with empty.

# %%
data.isnull().sum()
# Out:
# video_id         0
# title            0
# channel_id       0
# channel_title    0
# published_at     0
# view_count       0
# likes            0
# dislikes         0
# comment_count    0
# tags             0
# description      0
# comments         0
# dtype: int64

# %% [markdown]
# # 4. Check the statistical summary of both numerical and categorical columns and write your inferences.

# %%
data.describe()
# Out:
#          view_count         likes      dislikes  comment_count
# count  3.742200e+04  3.742200e+04  3.742200e+04   3.742200e+04
# mean   5.697838e+06  1.668147e+05  4.989862e+03   9.924930e+03
# std    2.426622e+07  5.375670e+05  3.070824e+04   1.171003e+05
# min    2.036800e+04  0.000000e+00  0.000000e+00   0.000000e+00
# 25%    5.122970e+05  1.323350e+04  2.810000e+02   9.000000e+02
# 50%    1.319078e+06  4.233050e+04  7.960000e+02   2.328000e+03
# 75%    3.670231e+06  1.304698e+05  2.461750e+03   6.184000e+03
# max    1.322797e+09  3.183768e+07  2.397733e+06   1.607103e+07

# %%
# Infrences 

#1) From above dataframe the count of the 37422 where likes and dislikes and comment_count has the same count.
#2) The average views_count for a vedio is 5697838 where the views_count has the highest average value when comparing to the likes
    # dislikes and comment_count.where as the likes has the least average that is 1.668147.
#3) The standard deviation tells us how much the observations in a dataset deviate from the average value.where standard deviation
     # for the following are view=	2.426622e+07.
#4) The minimum view_count for a purticular vedio is 2.036800e+ where as there are no likes,dislikes and comment_count for the purticulalr vedios. 
#5) The maximun view_count for a purticular vedio is 1.322797e+09 where as the maximunm likes are 3.183768e+07 , maximum dilikes
    # are 2.397733e+06 and the maximum comment_count is 1.607103e+07 for a purticular vedios.

# %%
data.describe(include='object')
# Out:
#            video_id  title                channel_id        channel_title  \
# count         37422  37422                     37422                37422
# unique        37422  37113                     10961                10883
# top     --0bCF-iK2E    www  UCNAf1k0yIjyGu3k9BwAg3lg  Sky Sports Football
# freq              1     21                       533                  533
#
#                published_at   tags description comments published_month
# count                 37422  37422       37422    37422           37422
# unique                36772  28799       35630    37265              12
# top     2020-10-16 04:00:10                                         Oct
# freq                      6   3817         589      158            4991

# %%
#Infrences

#1)There are 37422 unique vedios,3713 unique titlel,10961 unique channel_id,10883 unique channel_title,37265 unique comments
#2)The top vedio_id is --0bCF-iK2E

# %% [markdown]
# # 5. Convert datatype of column published_at from object to pandas datetime.

# %%
data.dtypes
# Out:
# video_id         object
# title            object
# channel_id       object
# channel_title    object
# published_at     object
# view_count        int64
# likes             int64
# dislikes          int64
# comment_count     int64
# tags             object
# description      object
# comments         object
# dtype: object

# %%
data['published_at'] = pd.to_datetime(data['published_at'])

# %%
data
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %%
data.dtypes #converting the published_at in to the datetime.
# Out:
# video_id                 object
# title                    object
# channel_id               object
# channel_title            object
# published_at     datetime64[ns]
# view_count                int64
# likes                     int64
# dislikes                  int64
# comment_count             int64
# tags                     object
# description              object
# comments                 object
# dtype: object

# %% [markdown]
# ### 6. Create a new column as 'published_month' using the column published_at (display the months only)

# %%
data['published_month'] = pd.DatetimeIndex(data['published_at']).month

# %%
data
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %% [markdown]
# ### 7)Replace the numbers in the column published_month as names of the months i,e., 1 as 'Jan', 2 as 'Feb'and so on.....

# %%
month_name={1:"Jan",2:"Feb",3:"Mar",4:"Apr",5:"May",6:"Jun",7:"Jul",8:"Aug",9:"Sep",10:"Oct",11:"Nov",12:"Dec"}
data['published_month']=data['published_month'].map(month_name)

# %%
data
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title        published_at  \
# ...

# %% [markdown]
# ### 8.Find the number of videos published each month and arrange the months in a decreasing order basedon the video count.

# %%
# count of videos published each month
month_counts = data.groupby('published_month')['video_id'].count().sort_values(ascending=False)
                                     
print(month_counts)
# Out:
# published_month
# Oct    4991
# Sep    4880
# Nov    4851
# Aug    4262
# Dec    3072
# Jul    2340
# Jun    2316
# Mar    2258
# Feb    2137
# Apr    2126
# Jan    2108
# May    2081
# Name: video_id, dtype: int64

# %%
data
# Out:
#           video_id                                              title  \
# 0      --0bCF-iK2E               Jadon Sancho  Magical Skills & Goals
# 1      --14w5SOEUs                 Migos - Avalanche (Official Video)
# 2      --40TEbZ9Is         Supporting Actress in a Comedy: 73rd Emmys
# 3      --4tfbSyYDE            JO1'YOUNG (JO1 ver.)' PERFORMANCE VIDEO
# 4      --DKkzWVh-E                       Why Retaining Walls Collapse
# ...            ...                                                ...
# 37417  zzd4ydafGR0  Lil Tjay - Calling My Phone (feat. 6LACK) [Off...
# 37418  zziBybeSAtw  PELICANS at LAKERS | FULL GAME HIGHLIGHTS | Ja...
# 37419  zzk09ESX7e0                 [MV]  (MAMAMOO) - Where Are We Now
# 37420  zzmQEb0Em5I              FELLIPE ESCUDERO- Master Podcast  #12
# 37421  zzxPZwaA-8w  Gareth Bale brace secures dramatic comeback on...
#
#                      channel_id          channel_title         published_at  \
# ...

# %% [markdown]
# ### 9) Find the count of unique video_id, channel_id and channel_title.

# %%
unique_vedio=set(data["video_id"])  #The uniqie vedio_id are 37422
print(len(unique_vedio))
# Out:
# 37422

# %%
unique_channel_id=set(data["channel_id"]) #The unique_channel are 10961
print(len(unique_channel_id))
# Out:
# 10961

# %%
unique_tittle=set(data["channel_title"])  #The unique tittle are 10883
print(len(unique_tittle))
# Out:
# 10883

# %% [markdown]
# ### 10. Find the top10 channel names having the highest number of videos in the dataset and the bottom10
# having lowest number of videos.

# %%
channels=data.groupby("channel_title")["video_id"].count().sort_values(ascending=False)

# %%
channels
# Out:
# channel_title
# Sky Sports Football    533
# The United Stand       301
# BT Sport               246
# NBA                    209
# NFL                    162
#                       ...
# Kannada Cinema           1
# KanalD                   1
# Kanak News               1
# Kamille Ramos            1
# zoom                     1
# Name: video_id, Length: 10883, dtype: int64

# %%
channels[:10] #The top 10 channel names having the highest number of videos
# Out:
# channel_title
# Sky Sports Football    533
# The United Stand       301
# BT Sport               246
# NBA                    209
# NFL                    162
# WWE                    122
# SSSniperWolf            99
# SSundee                 98
# FORMULA 1               87
# NHL                     86
# Name: video_id, dtype: int64

# %%
channels[-10:]  #The bottom 10 channel names having the highest number of videos
# Out:
# channel_title
# Karchez           1
# Karate Combat     1
# Kaptain Kuba      1
# Kanye West        1
# Kannur kitchen    1
# Kannada Cinema    1
# KanalD            1
# Kanak News        1
# Kamille Ramos     1
# zoom              1
# Name: video_id, dtype: int64

# %% [markdown]
# ### 11. Find the title of the video which has the maximum number of likes and the title of the video having minimum likes and write your inferences.

# %%
likes_data=data['likes']
likes_data
# Out:
# 0          19515
# 1         359277
# 2          11212
# 3          39131
# 4          32887
#           ...
# 37417    2180780
# 37418      20759
# 37419     720854
# 37420      19198
# 37421      34063
# Name: likes, Length: 37422, dtype: int64

# %%
likes=data['likes']
videos=data['title']

# %%
maximum_likes=max(likes)

# %%
minimum_likes=min(likes)

# %%
for i in range(len(likes)):
    if likes[i]==maximum_likes:
        break
print('The title of the video with the maximum number of likes is:',videos[i])
# Out:
# The title of the video with the maximum number of likes is: BTS () 'Dynamite' Official MV

# %%
for i in range(len(likes)):
    if likes[i]==minimum_likes:
        break
print(f'The title of the video with the minimum number of likes is:',videos[i])
# Out:
# The title of the video with the minimum number of likes is: Kim Kardashian's Must-See Moments on "Saturday Night Live" | E! News

# %%
#Infrences 
#1) The maximum_likes vedio title is BTS () 'Dynamite' Official MV
#2) The minimu_likes vedio title is Kim Kardashian's Must-See Moments on "Saturday Night Live" | E! News

# %% [markdown]
# ### 12. Find the title of the video which has the maximum number of dislikes and the title of the video having minimum dislikes and write your inferences.

# %%
dislikes=data['dislikes']
videos1=data['title']

# %%
maximum_dislikes=max(dislikes)

# %%
minimum_dislikes=min(dislikes)

# %%
for i in range(len(dislikes)):
    if dislikes[i]==maximum_dislikes:
        break
print('The title of the video with the maximum number of dislikes is:',videos[i])
# Out:
# The title of the video with the maximum number of likes is: Cuties | Official Trailer | Netflix

# %%
for i in range(len(dislikes)):
    if dislikes[i]==minimum_dislikes:
        break
print(f'The title of the video with the minimum number of dislikes is:',videos[i])
# Out:
# The title of the video with the minimum number of likes is: Kim Kardashian's Must-See Moments on "Saturday Night Live" | E! News

# %%
#Infrences 
#1) The maximum_dislikes vedio title is Cuties | Official Trailer | Netflix
#2) The minimu_dislikes vedio title is Kim Kardashian's Must-See Moments on "Saturday Night Live" | E! News

# %% [markdown]
# ### 13. Does the number of views have any effect on how many people disliked the video? Support your answer with a metric and a plot.

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.scatter(data['view_count'], data['dislikes'])
plt.xlabel('Views')
plt.ylabel('Dislikes')
plt.title('Views vs Dislikes')
plt.show()

# %%
corr=data["view_count"].corr(data["dislikes"])

# %%
corr
# Out:
# 0.6844687753905547

# %% [markdown]
# 1)From the scatter plot we can say that number of views doesnot have any effect on how many people #disliked the video
#   the most scatter plot where depends on where with the number of views is more and the diskiles also increases

# %%
# 1)From the scatter plot we can say that number of views doesnot have any effect on how many people 
   #disliked the video, the most scatter plot where depends on where with the number of views is more 
    # and the diskiles also increases so there is no effect on the views but with increase in views 
    # the dislikes also increases
#2) Form the correlation aslo we can say that there is no effect in the views with the number of dislikes
    # but there is a stronge corelation that with increase in views the dislikes also increases.

# %% [markdown]
# ### 14. Display all the information about the videos that were published in January, and mention the count of videos that were published in January.

# %%
jan_videos = data[data['published_month'] == 'Jan'] 

print(jan_videos.describe())

print('Number of videos published in January:', jan_videos.shape[0])

# The number of videos published in january is 2108.
# Out:
#          view_count         likes       dislikes  comment_count
# count  2.108000e+03  2.108000e+03    2108.000000   2.108000e+03
# mean   4.976449e+06  1.315030e+05    3614.568311   8.923385e+03
# std    2.055331e+07  3.886887e+05   13946.711333   3.664662e+04
# min    2.845000e+04  2.800000e+01       3.000000   0.000000e+00
# 25%    4.322335e+05  1.032400e+04     249.000000   8.747500e+02
# 50%    1.147500e+06  3.173900e+04     729.000000   2.328500e+03
# 75%    3.227483e+06  1.076512e+05    2243.250000   6.302000e+03
# max    6.203274e+08  7.828036e+06  409144.000000   1.095119e+06
# Number of videos published in January: 2108
